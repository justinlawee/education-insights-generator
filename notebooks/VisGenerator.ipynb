# %%
from google.colab import drive
import os

drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/MyDrive/colab_project')

# !pip install -r requirements.txt
# !pip install PyMuPDF python-pptx pandas openpyxl python-docx kaleido

import sys

if "google.colab" in sys.modules:
    from google.colab import auth as google_auth

    google_auth.authenticate_user()
# Out:
# Mounted at /content/drive
# Collecting db-dtypes==1.4.0 (from -r requirements.txt (line 1))
#   Downloading db_dtypes-1.4.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-google-vertexai==2.0.11 (from -r requirements.txt (line 2))
#   Downloading langchain_google_vertexai-2.0.11-py3-none-any.whl.metadata (3.8 kB)
# Collecting langchain-google-community==2.0.1 (from -r requirements.txt (line 3))
#   Downloading langchain_google_community-2.0.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting google-cloud-discoveryengine==0.13.3 (from -r requirements.txt (line 4))
#   Downloading google_cloud_discoveryengine-0.13.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting google-cloud-bigquery-storage==2.27.0 (from -r requirements.txt (line 5))
#   Downloading google_cloud_bigquery_storage-2.27.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting langgraph==0.2.67 (from -r requirements.txt (line 6))
#   Downloading langgraph-0.2.67-py3-none-any.whl.metadata (16 kB)
# Collecting google-cloud-bigquery==3.29.0 (from -r requirements.txt (line 7))
#   Downloading google_cloud_bigquery-3.29.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting langchain-groq==0.2.4 (from -r requirements.txt (line 8))
#   Downloading langchain_groq-0.2.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting plotly==6.0.0 (from -r requirements.txt (line 9))
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbformat==5.10.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.10.4)
# Collecting streamlit==1.41.1 (from -r requirements.txt (line 11))
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 12))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from db-dtypes==1.4.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyarrow>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from db-dtypes==1.4.0->-r requirements.txt (line 1)) (18.1.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.11/dist-packages (from db-dtypes==1.4.0->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.75.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (1.92.0)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (2.19.0)
# Requirement already satisfied: httpx<0.29.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (0.28.1)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-google-vertexai==2.0.11->-r requirements.txt (line 2))
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3.27 in /usr/local/lib/python3.11/dist-packages (from langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (0.3.59)
# Collecting pydantic<2.10,>=2.9 (from langchain-google-vertexai==2.0.11->-r requirements.txt (line 2))
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core<3.0.0,>=2.17.1 in /usr/local/lib/python3.11/dist-packages (from langchain-google-community==2.0.1->-r requirements.txt (line 3)) (2.24.2)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.122.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-community==2.0.1->-r requirements.txt (line 3)) (2.169.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from langchain-google-community==2.0.1->-r requirements.txt (line 3)) (2.4.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.62.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-community==2.0.1->-r requirements.txt (line 3)) (1.71.0)
# Collecting langchain-community<0.4.0,>=0.3.0 (from langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading langchain_community-0.3.24-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (5.29.4)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.10 (from langgraph==0.2.67->-r requirements.txt (line 6))
#   Downloading langgraph_checkpoint-2.0.26-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph==0.2.67->-r requirements.txt (line 6))
#   Downloading langgraph_sdk-0.1.70-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery==3.29.0->-r requirements.txt (line 7)) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery==3.29.0->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery==3.29.0->-r requirements.txt (line 7)) (2.32.3)
# Collecting groq<1,>=0.4.1 (from langchain-groq==0.2.4->-r requirements.txt (line 8))
#   Downloading groq-0.25.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly==6.0.0->-r requirements.txt (line 9)) (1.39.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat==5.10.4->-r requirements.txt (line 10)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat==5.10.4->-r requirements.txt (line 10)) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat==5.10.4->-r requirements.txt (line 10)) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.11/dist-packages (from nbformat==5.10.4->-r requirements.txt (line 10)) (5.7.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (8.2.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (11.2.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (4.13.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit==1.41.1->-r requirements.txt (line 11))
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit==1.41.1->-r requirements.txt (line 11))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit==1.41.1->-r requirements.txt (line 11)) (6.4.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.3->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.3->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit==1.41.1->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.41.1->-r requirements.txt (line 11)) (4.0.12)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.17.1->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (1.71.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.122.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.122.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client<3.0.0,>=2.122.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.75.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.75.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.75.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.75.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (0.16)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.4->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.4->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.4->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.28.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.28.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29.0,>=0.28.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29.0,>=0.28.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 10)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 10)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 10)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 10)) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat==5.10.4->-r requirements.txt (line 10)) (4.3.8)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (2.0.40)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (3.11.15)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.3.42)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.27->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (1.33)
# Collecting ormsgpack<2.0.0,>=1.8.0 (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph==0.2.67->-r requirements.txt (line 6))
#   Downloading ormsgpack-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph==0.2.67->-r requirements.txt (line 6)) (3.10.18)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.10,>=2.9->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (0.7.0)
# Collecting pydantic-core==2.23.4 (from pydantic<2.10,>=2.9->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2))
#   Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery==3.29.0->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery==3.29.0->-r requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery==3.29.0->-r requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit==1.41.1->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit==1.41.1->-r requirements.txt (line 11)) (2.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (1.20.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.41.1->-r requirements.txt (line 11)) (5.0.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.75.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (0.14.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform<2.0.0,>=1.75.0->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.122.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit==1.41.1->-r requirements.txt (line 11)) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.27->langchain-google-vertexai==2.0.11->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.25->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.41.1->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine==0.13.3->-r requirements.txt (line 4)) (0.6.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3)) (3.2.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-google-community==2.0.1->-r requirements.txt (line 3))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading db_dtypes-1.4.0-py2.py3-none-any.whl (19 kB)
# Downloading langchain_google_vertexai-2.0.11-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 6.7 MB/s eta 0:00:00
# Downloading langchain_google_community-2.0.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.7 MB/s eta 0:00:00
# Downloading google_cloud_discoveryengine-0.13.3-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 5.2 MB/s eta 0:00:00
# Downloading google_cloud_bigquery_storage-2.27.0-py2.py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 21.1 MB/s eta 0:00:00
# Downloading langgraph-0.2.67-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 11.8 MB/s eta 0:00:00
# Downloading google_cloud_bigquery-3.29.0-py2.py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.6/244.6 kB 17.4 MB/s eta 0:00:00
# Downloading langchain_groq-0.2.4-py3-none-any.whl (14 kB)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 99.4 MB/s eta 0:00:00
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 94.1 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 95.1 MB/s eta 0:00:00
# Downloading groq-0.25.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 10.3 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_community-0.3.24-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 19.7 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.0.26-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 3.5 MB/s eta 0:00:00
# Downloading langgraph_sdk-0.1.70-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 4.1 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 31.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.5 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 97.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.6 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading ormsgpack-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 15.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.3 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: watchdog, python-dotenv, pydantic-core, plotly, ormsgpack, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydeck, pydantic, pandas, pydantic-settings, langgraph-sdk, groq, db-dtypes, dataclasses-json, streamlit, langgraph-checkpoint, langchain-groq, google-cloud-discoveryengine, google-cloud-bigquery-storage, google-cloud-bigquery, langgraph, langchain-google-vertexai, langchain-community, langchain-google-community
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.4
#     Uninstalling pydantic-2.11.4:
#       Successfully uninstalled pydantic-2.11.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: db-dtypes
#     Found existing installation: db-dtypes 1.4.3
#     Uninstalling db-dtypes-1.4.3:
#       Successfully uninstalled db-dtypes-1.4.3
#   Attempting uninstall: google-cloud-bigquery-storage
#     Found existing installation: google-cloud-bigquery-storage 2.31.0
#     Uninstalling google-cloud-bigquery-storage-2.31.0:
#       Successfully uninstalled google-cloud-bigquery-storage-2.31.0
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 3.32.0
#     Uninstalling google-cloud-bigquery-3.32.0:
#       Successfully uninstalled google-cloud-bigquery-3.32.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# bigframes 2.4.0 requires db-dtypes>=1.4.2, but you have db-dtypes 1.4.0 which is incompatible.
# bigframes 2.4.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.29.0 which is incompatible.
# bigframes 2.4.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, but you have google-cloud-bigquery-storage 2.27.0 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 db-dtypes-1.4.0 google-cloud-bigquery-3.29.0 google-cloud-bigquery-storage-2.27.0 google-cloud-discoveryengine-0.13.3 groq-0.25.0 httpx-sse-0.4.0 langchain-community-0.3.24 langchain-google-community-2.0.1 langchain-google-vertexai-2.0.11 langchain-groq-0.2.4 langgraph-0.2.67 langgraph-checkpoint-2.0.26 langgraph-sdk-0.1.70 marshmallow-3.26.1 mypy-extensions-1.1.0 ormsgpack-1.10.0 pandas-2.2.3 plotly-6.0.0 pydantic-2.9.2 pydantic-core-2.23.4 pydantic-settings-2.9.1 pydeck-0.9.1 python-dotenv-1.1.0 streamlit-1.41.1 typing-inspect-0.9.0 watchdog-6.0.0
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Collecting python-pptx
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (11.2.1)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading XlsxWriter-3.2.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-pptx) (4.13.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 78.1 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 29.6 MB/s eta 0:00:00
# Downloading XlsxWriter-3.2.3-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 12.5 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter, PyMuPDF, python-pptx
# Successfully installed PyMuPDF-1.26.0 XlsxWriter-3.2.3 python-pptx-1.0.2
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.13.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
MODEL_PRICING = {
    "gemini-2.5-pro-preview-05-06": {
        "input_cost_per_1M_tokens": 1.25,
        "output_cost_per_1M_tokens": 10
    },
    "gemini-2.5-flash-preview-04-17": {
        "input_cost_per_1M_tokens": 0.15,
        "output_cost_per_1M_tokens": 0.6
    },
    "gemini-2.0-flash": {
        "input_cost_per_1M_tokens": 0.1,
        "output_cost_per_1M_tokens": 0.4
    },
    "gemini-2.0-flash-lite": {
        "input_cost_per_1M_tokens": 0.075,
        "output_cost_per_1M_tokens": 0.3
    }
}

agent_llm_list = [['sql_writer', 'sql_writer_generation'],
                  ['sql_validator', 'sql_validator'],
                  ['sql_judge', 'sql_writer_judge'],
                  ['bi_expert', 'bi_expert_generation'],
                  ['bi_judge', 'bi_expert_judge'],
                  ['python_writer', 'py_gen_generation'],
                  ['python_validator', 'py_fixer'],
                  ['python_judge', 'py_gen_judge'],
                  ['insights_generator', 'insights_generator'],
                  ['insights_judge', 'insights_judge']
                  ]

def calculate_llm_cost(final_state):
    total_cost = 0
    input_tokens = 0
    output_tokens = 0

    for agent_llm in agent_llm_list:
        llm_config = final_state[f'llm_config_{agent_llm[0]}']
        input_token_name = f'{agent_llm[1]}_input_tokens'
        output_token_name = f'{agent_llm[1]}_output_tokens'
        model_used = llm_config['model_name']
        input_cost = MODEL_PRICING[model_used]['input_cost_per_1M_tokens'] * final_state[
            input_token_name] / 1000000.0
        output_cost = MODEL_PRICING[model_used]['output_cost_per_1M_tokens'] * final_state[
            output_token_name] / 1000000.0
        total_cost += input_cost + output_cost
        input_tokens += final_state[input_token_name]
        output_tokens += final_state[output_token_name]

    return total_cost, input_tokens, output_tokens

# calculate_llm_cost(final_state)

# %%
import workflow
import importlib # Import the importlib module
importlib.reload(workflow) # This reloads your main workflow.py

USER_STORIES_DOCX_PATH="/content/drive/My Drive/Datasets/User Stories/User Stories - March 2025_.docx"
MTSS_DOCS_FOLDER_PATH = "/content/drive/My Drive/Datasets/MTSS Documentation"
CORR_DATA_FILE1_PATH = "/content/drive/My Drive/Datasets/IAR_ELA.csv"
CORR_DATA_FILE2_PATH = "/content/drive/My Drive/Datasets/IAR_MATH.csv"

user_stories_text_content = workflow.read_docx(USER_STORIES_DOCX_PATH).strip()
mtss_docs_text_content = workflow.load_mtss_documentation_context(MTSS_DOCS_FOLDER_PATH).strip()
correlations_string_summary = workflow.full_correlation_analysis_string(CORR_DATA_FILE1_PATH, CORR_DATA_FILE2_PATH).strip()
# Out:
# Correlation datasets loaded and merged successfully.

# %%
from ast import mod
import prompts
import workflow
import time
importlib.reload(prompts) # This reloads your main workflow.py
importlib.reload(workflow) # This reloads your main workflow.py


question = """What is the distribution of (Annual Grade) for students at each (Grade Level Current)?"""
model = "gemini-2.0-flash"
start_time = time.time()
final_state = workflow.run_workflow(question,
                                    user_stories_text=user_stories_text_content,
                                    mtss_docs_text=mtss_docs_text_content,
                                    correlations_text=correlations_string_summary,

                                    sql_writer_n_runs=3,
                                    bi_expert_n_runs=3,
                                    py_gen_n_runs=3,
                                    insights_n_runs=3,

                                    llm_sql_writer_model_name=model,
                                    llm_sql_validator_model_name=model,
                                    llm_sql_judge_model_name=model,
                                    llm_bi_expert_model_name=model,
                                    llm_bi_judge_model_name=model,
                                    llm_python_writer_model_name=model,
                                    llm_python_validator_model_name=model,
                                    llm_python_judge_model_name=model,
                                    llm_insights_generator_model_name=model,
                                    llm_insights_judge_model_name=model
                                    )
calculate_llm_cost(final_state)
print(time.time() - start_time)
# Out:
# Streaming output truncated to the last 5000 lines.
#                                ' \xa0 management\t\r'
#                                ' \xa0 issues),\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'learner\t\r'
#                                ' \xa0 (e.g.,\t\r'
#                                ' \xa0 skill\t\r'
#                                ' \xa0 deficits)\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 why\t\r'
#                                ' \xa0 the\t\r'
#                                ' \xa0 student\t\r'
#                                ' \xa0 is\t\r'
#                                ' \xa0 not\t\r'
#                                ' \xa0 meeting\t\r'
#                                ' \xa0 expectations\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 collect\t\r'
#                                ' \xa0\n'
#                                'data/information\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0determine\t\r'
#                                ' \xa0which\t\r'
#                                ' \xa0reasons\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0contributing\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0problem.\t\r'
#                                ' \xa0\n'
#                                '20. Specific\t\r'
#                                ' \xa0instruction/intervention\t\r'
#                                ' \xa0plans\t\r'
#                                ' \xa0include\t\r'
#                                ' \xa0information\t\r'
#                                ' \xa0outlining:\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'The\t\r'
#                                ' \xa0goal\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0intervention/action\t\r'
#                                ' \xa0plan\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'What\t\r'
#                                ' \xa0intervention\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0action\t\r'
#                                ' \xa0steps\t\r'
#                                ' \xa0(e.g.,\t\r'
#                                ' \xa0curriculum\t\r'
#                                ' \xa0adjustments,\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0processes\t\r'
#                                ' \xa0\n'
#                                'and\t\r'
#                                ' \xa0procedures)\t\r'
#                                ' \xa0will\t\r'
#                                ' \xa0be\t\r'
#                                ' \xa0put\t\r'
#                                ' \xa0in\t\r'
#                                ' \xa0place\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'How\t\r'
#                                ' \xa0often\t\r'
#                                ' \xa0(daily/weekly/etc.)\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0intervention\t\r'
#                                ' \xa0will\t\r'
#                                ' \xa0be\t\r'
#                                ' \xa0utilized\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'How\t\r'
#                                ' \xa0long\t\r'
#                                ' \xa0each\t\r'
#                                ' \xa0session\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0be\t\r'
#                                ' \xa0implemented\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'Who\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0responsible\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0intervention\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'Where\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0when\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0intervention\t\r'
#                                ' \xa0will\t\r'
#                                ' \xa0happen\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'Plan\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0monitoring\t\r'
#                                ' \xa0instruction/intervention\t\r'
#                                ' \xa0fidelity\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0progress\t\r'
#                                ' \xa0towards\t\r'
#                                ' \xa0identified\t\r'
#                                ' \xa0goals\t\r'
#                                ' \xa0\n'
#                                '• \n'
#                                'Timeframe\t\r'
#                                ' \xa0(dates)\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0periodic\t\r'
#                                ' \xa0review\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0progress\t\r'
#                                ' \xa0monitoring\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0decision\t\r'
#                                ' \xa0points\t\r'
#                                ' \xa0\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                '21. Structured\t\r'
#                                ' \xa0 problem\t\r'
#                                ' \xa0 solving\t\r'
#                                ' \xa0 is\t\r'
#                                ' \xa0 utilized\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 identify\t\r'
#                                ' \xa0 resources\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 can\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 used\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 facilitate\t\r'
#                                ' \xa0\n'
#                                'implementation\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 barriers\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 hindering\t\r'
#                                ' \xa0 implementation\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 the\t\r'
#                                ' \xa0 purpose\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0\n'
#                                'developing\t\r'
#                                ' \xa0specific\t\r'
#                                ' \xa0action\t\r'
#                                ' \xa0plans\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0increase\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0levels.\t\r'
#                                ' \xa0\n'
#                                '22. Priority\t\r'
#                                ' \xa0learning\t\r'
#                                ' \xa0standards\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0curriculum\t\r'
#                                ' \xa0standards\t\r'
#                                ' \xa0that\t\r'
#                                ' \xa0define\t\r'
#                                ' \xa0what\t\r'
#                                ' \xa0students\t\r'
#                                ' \xa0should\t\r'
#                                ' \xa0know\t\r'
#                                ' \xa0\n'
#                                'and\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 able\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 do\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 a\t\r'
#                                ' \xa0 given\t\r'
#                                ' \xa0 content\t\r'
#                                ' \xa0 area\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 grade\t\r'
#                                ' \xa0 level\t\r'
#                                ' \xa0 (e.g.,\t\r'
#                                ' \xa0 Common\t\r'
#                                ' \xa0 Core\t\r'
#                                ' \xa0 State\t\r'
#                                ' \xa0\n'
#                                'Standards;\t\r'
#                                ' \xa0state\t\r'
#                                ' \xa0specific\t\r'
#                                ' \xa0standards,\t\r'
#                                ' \xa0Social-\xad‐Emotional\t\r'
#                                ' \xa0Learning\t\r'
#                                ' \xa0Standards).\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '23. Expectations\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0often\t\r'
#                                ' \xa0include\t\r'
#                                ' \xa0elements\t\r'
#                                ' \xa0related\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0routine\t\r'
#                                ' \xa0(e.g.,\t\r'
#                                ' \xa0\n'
#                                'whole-\xad‐group,\t\r'
#                                ' \xa0 small-\xad‐group,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 independent\t\r'
#                                ' \xa0 practice),\t\r'
#                                ' \xa0 amount\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 time\t\r'
#                                ' \xa0 dedicated\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0\n'
#                                'instruction,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0which\t\r'
#                                ' \xa0evidence-\xad‐based\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0strategies\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0used.\t\r'
#                                ' \xa0\n'
#                                '24. Both\t\r'
#                                ' \xa0 statewide\t\r'
#                                ' \xa0 assessments\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 formative\t\r'
#                                ' \xa0 assessments\t\r'
#                                ' \xa0 administered\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 all\t\r'
#                                ' \xa0 students\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0\n'
#                                'important\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 identify\t\r'
#                                ' \xa0 so\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 expectations\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 the\t\r'
#                                ' \xa0 data\t\r'
#                                ' \xa0 needed\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 inform\t\r'
#                                ' \xa0 decisions\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0\n'
#                                'consistent.\t\r'
#                                ' \xa0\n'
#                                '\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                'SAM\t\r'
#                                ' \xa0Version\t\r'
#                                ' \xa02.0\t\r'
#                                ' \xa0(October\t\r'
#                                ' \xa02015)\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0-\xad‐\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0Page\t\r'
#                                ' \xa04\t\r'
#                                ' \xa0\n'
#                                '25. Structured\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0behavioral\t\r'
#                                ' \xa0expectations\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0emotional\t\r'
#                                ' \xa0skills\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0provided\t\r'
#                                ' \xa0\n'
#                                'to\t\r'
#                                ' \xa0 all\t\r'
#                                ' \xa0 students.\t\r'
#                                ' \xa0 Classroom\t\r'
#                                ' \xa0 routines\t\r'
#                                ' \xa0 include\t\r'
#                                ' \xa0 social\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 emotional\t\r'
#                                ' \xa0 learning\t\r'
#                                ' \xa0 principles\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'classroom\t\r'
#                                ' \xa0 management\t\r'
#                                ' \xa0 strategies\t\r'
#                                ' \xa0 embedded\t\r'
#                                ' \xa0 into\t\r'
#                                ' \xa0 instruction.\t\r'
#                                ' \xa0 School\t\r'
#                                ' \xa0 climate\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'environments\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0well-\xad‐being.\t\r'
#                                ' \xa0A\t\r'
#                                ' \xa0small\t\r'
#                                ' \xa0number\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0clearly\t\r'
#                                ' \xa0defined\t\r'
#                                ' \xa0school-\xad‐wide\t\r'
#                                ' \xa0\n'
#                                'expectations\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 positively\t\r'
#                                ' \xa0 stated\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 a\t\r'
#                                ' \xa0 foundational\t\r'
#                                ' \xa0 element\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 Tier\t\r'
#                                ' \xa0 1\t\r'
#                                ' \xa0 school-\xad‐wide\t\r'
#                                ' \xa0\n'
#                                'behavior\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0system.\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '26. School-\xad‐wide\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0 behavior\t\r'
#                                ' \xa0 data\t\r'
#                                ' \xa0 may\t\r'
#                                ' \xa0 include\t\r'
#                                ' \xa0 Office\t\r'
#                                ' \xa0 Discipline\t\r'
#                                ' \xa0 Referrals,\t\r'
#                                ' \xa0 In-\xad‐\n'
#                                'School\t\r'
#                                ' \xa0 Suspensions,\t\r'
#                                ' \xa0 Out-\xad‐of-\xad‐School\t\r'
#                                ' \xa0 Suspensions,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0 screening\t\r'
#                                ' \xa0 data\t\r'
#                                ' \xa0\n'
#                                'sources\t\r'
#                                ' \xa0used\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0examine\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0effectiveness\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0behavior\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0supports.\t\r'
#                                ' \xa0\n'
#                                '27. Tier\t\r'
#                                ' \xa0 2\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 should\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 aligned\t\r'
#                                ' \xa0 with\t\r'
#                                ' \xa0 Tier\t\r'
#                                ' \xa0 1\t\r'
#                                ' \xa0 instructional\t\r'
#                                ' \xa0 goals\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 expectations,\t\r'
#                                ' \xa0\n'
#                                'address\t\r'
#                                ' \xa0 high-\xad‐probability\t\r'
#                                ' \xa0 barriers\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 achieving\t\r'
#                                ' \xa0 instructional\t\r'
#                                ' \xa0 goals\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 expectations,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'include\t\r'
#                                ' \xa0assessments\t\r'
#                                ' \xa0which\t\r'
#                                ' \xa0measure\t\r'
#                                ' \xa0specific\t\r'
#                                ' \xa0skills,\t\r'
#                                ' \xa0general\t\r'
#                                ' \xa0outcomes,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0progress.\t\r'
#                                ' \xa0\n'
#                                '28. Tier\t\r'
#                                ' \xa0 2\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 should\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 aligned\t\r'
#                                ' \xa0 with\t\r'
#                                ' \xa0 school-\xad‐wide\t\r'
#                                ' \xa0 behavior\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0\n'
#                                'expectations,\t\r'
#                                ' \xa0address\t\r'
#                                ' \xa0high-\xad‐probability\t\r'
#                                ' \xa0barriers\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0meeting\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0goals\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0\n'
#                                'well-\xad‐being,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 include\t\r'
#                                ' \xa0 assessments\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 monitor\t\r'
#                                ' \xa0 student\t\r'
#                                ' \xa0 discipline\t\r'
#                                ' \xa0 incidents,\t\r'
#                                ' \xa0 social-\xad‐\n'
#                                'emotional\t\r'
#                                ' \xa0skills,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0well-\xad‐being.\t\r'
#                                ' \xa0\n'
#                                '29. Tier\t\r'
#                                ' \xa0 3\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 generally\t\r'
#                                ' \xa0 provide\t\r'
#                                ' \xa0 increased\t\r'
#                                ' \xa0 exposure\t\r'
#                                ' \xa0 (time\t\r'
#                                ' \xa0 in\t\r'
#                                ' \xa0 minutes)\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 quality\t\r'
#                                ' \xa0\n'
#                                'instruction\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0intervention,\t\r'
#                                ' \xa0more\t\r'
#                                ' \xa0focused\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0matched\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0need,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0smaller\t\r'
#                                ' \xa0\n'
#                                'groupings.\t\r'
#                                ' \xa0Additionally,\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa03\t\r'
#                                ' \xa0interventions\t\r'
#                                ' \xa0often\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0developed\t\r'
#                                ' \xa0during\t\r'
#                                ' \xa0individual\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0\n'
#                                'focused\t\r'
#                                ' \xa0 problem-\xad‐solving\t\r'
#                                ' \xa0 sessions.\t\r'
#                                ' \xa0 Importantly,\t\r'
#                                ' \xa0 Tier\t\r'
#                                ' \xa0 3\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 focused\t\r'
#                                ' \xa0 on\t\r'
#                                ' \xa0 academic\t\r'
#                                ' \xa0\n'
#                                'issues\t\r'
#                                ' \xa0should\t\r'
#                                ' \xa0be\t\r'
#                                ' \xa0linked\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa02\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0content\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0processes\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0also\t\r'
#                                ' \xa0should\t\r'
#                                ' \xa0\n'
#                                'consider\t\r'
#                                ' \xa0what\t\r'
#                                ' \xa0behavioral\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0supports\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0needed\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0success.\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '30. Tier\t\r'
#                                ' \xa0 3\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 matched\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 a\t\r'
#                                ' \xa0 student’s\t\r'
#                                ' \xa0 specific\t\r'
#                                ' \xa0 behavior\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0\n'
#                                'needs\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0ensure\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0has\t\r'
#                                ' \xa0access\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa02\t\r'
#                                ' \xa0supports.\t\r'
#                                ' \xa0For\t\r'
#                                ' \xa0a\t\r'
#                                ' \xa0few\t\r'
#                                ' \xa0students\t\r'
#                                ' \xa0\n'
#                                'with\t\r'
#                                ' \xa0complex\t\r'
#                                ' \xa0needs,\t\r'
#                                ' \xa0individualized\t\r'
#                                ' \xa0interventions\t\r'
#                                ' \xa0may\t\r'
#                                ' \xa0involve\t\r'
#                                ' \xa0wraparound\t\r'
#                                ' \xa0supports\t\r'
#                                ' \xa0across\t\r'
#                                ' \xa0\n'
#                                'systems\t\r'
#                                ' \xa0(e.g.,\t\r'
#                                ' \xa0mental\t\r'
#                                ' \xa0health,\t\r'
#                                ' \xa0education,\t\r'
#                                ' \xa0medical,\t\r'
#                                ' \xa0family,\t\r'
#                                ' \xa0etc.).\t\r'
#                                ' \xa0Individualized\t\r'
#                                ' \xa0interventions\t\r'
#                                ' \xa0\n'
#                                'include\t\r'
#                                ' \xa0 specific\t\r'
#                                ' \xa0 prevention\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 consequence-\xad‐based\t\r'
#                                ' \xa0 strategies\t\r'
#                                ' \xa0 based\t\r'
#                                ' \xa0 on\t\r'
#                                ' \xa0 assessment\t\r'
#                                ' \xa0\n'
#                                'information\t\r'
#                                ' \xa0(i.e.,\t\r'
#                                ' \xa0Functional\t\r'
#                                ' \xa0Behavior\t\r'
#                                ' \xa0Assessment),\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0may\t\r'
#                                ' \xa0include\t\r'
#                                ' \xa0modifications\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0\n'
#                                'classroom\t\r'
#                                ' \xa0 environment\t\r'
#                                ' \xa0 or\t\r'
#                                ' \xa0 instruction,\t\r'
#                                ' \xa0 teaching\t\r'
#                                ' \xa0 new\t\r'
#                                ' \xa0 skills,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 reinforcement\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 desired\t\r'
#                                ' \xa0\n'
#                                'behaviors\t\r'
#                                ' \xa0as\t\r'
#                                ' \xa0well\t\r'
#                                ' \xa0as\t\r'
#                                ' \xa0a\t\r'
#                                ' \xa0range\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0supports\t\r'
#                                ' \xa0such\t\r'
#                                ' \xa0as\t\r'
#                                ' \xa0mental\t\r'
#                                ' \xa0health\t\r'
#                                ' \xa0services.\t\r'
#                                ' \xa0\n'
#                                '31. District\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0states\t\r'
#                                ' \xa0typically\t\r'
#                                ' \xa0create\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0adopt\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0management\t\r'
#                                ' \xa0systems.\t\r'
#                                ' \xa0They\t\r'
#                                ' \xa0also\t\r'
#                                ' \xa0specify\t\r'
#                                ' \xa0\n'
#                                'access\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 use\t\r'
#                                ' \xa0 requirements.\t\r'
#                                ' \xa0 School\t\r'
#                                ' \xa0 leaders\t\r'
#                                ' \xa0 should\t\r'
#                                ' \xa0 coordinate\t\r'
#                                ' \xa0 with\t\r'
#                                ' \xa0 district\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 state\t\r'
#                                ' \xa0\n'
#                                'leaders\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0understand\t\r'
#                                ' \xa0requirements\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0establish\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0communicate\t\r'
#                                ' \xa0procedures\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0using\t\r'
#                                ' \xa0\n'
#                                'the\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0system\t\r'
#                                ' \xa0at\t\r'
#                                ' \xa0their\t\r'
#                                ' \xa0school.\t\r'
#                                ' \xa0Quality\t\r'
#                                ' \xa0indicators\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0management\t\r'
#                                ' \xa0systems\t\r'
#                                ' \xa0include:\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                'real-\xad‐time\t\r'
#                                ' \xa0relevant\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0academic,\t\r'
#                                ' \xa0behavior,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0content,\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0ability\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0\n'
#                                'graphically\t\r'
#                                ' \xa0 represent\t\r'
#                                ' \xa0 data,\t\r'
#                                ' \xa0 provision\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 tiered\t\r'
#                                ' \xa0 intervention\t\r'
#                                ' \xa0 data,\t\r'
#                                ' \xa0 integrated\t\r'
#                                ' \xa0 academic,\t\r'
#                                ' \xa0\n'
#                                'behavior,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0data,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0customizable\t\r'
#                                ' \xa0at\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0school\t\r'
#                                ' \xa0level.\t\r'
#                                ' \xa0\n'
#                                '\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                'SAM\t\r'
#                                ' \xa0Version\t\r'
#                                ' \xa02.0\t\r'
#                                ' \xa0(October\t\r'
#                                ' \xa02015)\t\r'
#                                ' \xa0\n'
#                                'SAM\t\r'
#                                ' \xa0Scoring\t\r'
#                                ' \xa0Sheet\t\r'
#                                ' \xa0\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                'THIS\t\r'
#                                ' \xa0SCORING\t\r'
#                                ' \xa0SHEET\t\r'
#                                ' \xa0HAS\t\r'
#                                ' \xa0ABBREVIATED\t\r'
#                                ' \xa0LANGUAGE\t\r'
#                                ' \xa0AND\t\r'
#                                ' \xa0SHOULD\t\r'
#                                ' \xa0ONLY\t\r'
#                                ' \xa0BE\t\r'
#                                ' \xa0USED\t\r'
#                                ' \xa0TO\t\r'
#                                ' \xa0RECORD\t\r'
#                                ' \xa0AND\t\r'
#                                ' \xa0DISPLAY\t\r'
#                                ' \xa0RESPONSES\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                'Rate\t\r'
#                                ' \xa0each\t\r'
#                                ' \xa0item\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0a\t\r'
#                                ' \xa0scale\t\r'
#                                ' \xa0from\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0(0\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Not\t\r'
#                                ' \xa0Started;\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Emerging/Developing;\t\r'
#                                ' \xa02\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Operationalizing;\t\r'
#                                ' \xa03\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Optimizing)\t\r'
#                                ' \xa0\n'
#                                '1.\t\r'
#                                ' \xa0Leadership\t\r'
#                                ' \xa0Domain\t\r'
#                                ' \xa0(Items\t\r'
#                                ' \xa01-\xad‐5)\t\r'
#                                ' \xa0\n'
#                                'Rating\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0\n'
#                                '1.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0principal\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0actively\t\r'
#                                ' \xa0involved\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '2.\t\r'
#                                ' \xa0A\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0established\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '3.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0actively\t\r'
#                                ' \xa0engages\t\r'
#                                ' \xa0in\t\r'
#                                ' \xa0ongoing\t\r'
#                                ' \xa0professional\t\r'
#                                ' \xa0development\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '4.\t\r'
#                                ' \xa0A\t\r'
#                                ' \xa0strategic\t\r'
#                                ' \xa0plan\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0developed\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '5.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0actively\t\r'
#                                ' \xa0facilitating\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '2.\t\r'
#                                ' \xa0Building\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0Capacity/Infrastructure\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0Implementation\t\r'
#                                ' \xa0Domain\t\r'
#                                ' \xa0(Items\t\r'
#                                ' \xa06-\xad‐16)\t\r'
#                                ' \xa0\n'
#                                'Rating\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0\n'
#                                '6.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0critical\t\r'
#                                ' \xa0elements\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0defined\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0understood\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '7.\t\r'
#                                ' \xa0Professional\t\r'
#                                ' \xa0development\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0coaching\t\r'
#                                ' \xa0provided\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0staff\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '8.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0facilitates\t\r'
#                                ' \xa0PD\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0data-\xad‐based\t\r'
#                                ' \xa0problem-\xad‐solving\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '9.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0facilitates\t\r'
#                                ' \xa0PD\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0multi-\xad‐tiered\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0intervention\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '10.\t\r'
#                                ' \xa0Coaching\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0used\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '11.\t\r'
#                                ' \xa0Schedules\t\r'
#                                ' \xa0provide\t\r'
#                                ' \xa0adequate\t\r'
#                                ' \xa0time\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0training\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0coaching\t\r'
#                                ' \xa0\n'
# ...
# Number of documents retrieved: 2
# Fetching schema for: nw-ai-lab.illinois_2025_nw.iar_math
# Fetching schema for: nw-ai-lab.illinois_2025_nw.iar_ela
# Database Schemas Found:
# Schema for table `nw-ai-lab.illinois_2025_nw.iar_math`:
# nw-ai-lab.illinois_2025_nw.iar_math
# - Student_Name (STRING): Full name of the student
# - Student_ID (INTEGER): Unique student identifier
# - Annual_Grade (INTEGER): Grade level for the academic year
# - Test_Grade (INTEGER): Grade level at which the test was taken
# - Grade_Level_Current (INTEGER): Current grade level of the student
# - Current_Homeroom (STRING): Homeroom assignment (if available)
# - Tested_School (STRING): Name of the school where the test was taken
# - Current_School (STRING): Name of the student's current school
# - Product (STRING): Name of the assessment (IAR)
# - Test_Scaled_Score (INTEGER): Scaled score of the test (ranges from 650 to 850)
# - Student_Growth_Percentile (STRING): Student’s growth percentile (missing values represented as `--`)
# - Subject_Category (STRING): Subject of the test (Mathematics)
# - Test_Primary_Result_Code (STRING): Performance level (e.g., 'Did Not Yet Meet Expectations')
# - Year (STRING): Academic year when the test was taken (format: YYYY-YYYY)
# ---------------
# Schema for table `nw-ai-lab.illinois_2025_nw.iar_ela`:
# nw-ai-lab.illinois_2025_nw.iar_ela
# - Student_Name (STRING): Full name of the student
# - Student_ID (INTEGER): Unique student identifier
# - Annual_Grade (INTEGER): Grade level for the academic year
# - Test_Grade (INTEGER): Grade level at which the test was taken
# - Grade_Level_Current (INTEGER): Current grade level of the student
# - Current_Homeroom (STRING): Homeroom assignment (if available)
# - Tested_School (STRING): Name of the school where the test was taken
# - Current_School (STRING): Name of the student's current school
# - Product (STRING): Name of the assessment (IAR)
# - Test_Scaled_Score (INTEGER): Scaled score of the test (ranges from 650 to 850)
# - Student_Growth_Percentile (STRING): Student’s growth percentile (missing values represented as `--`)
# - Subject_Category (STRING): Subject of the test (ELA)
# - Test_Primary_Result_Code (STRING): Performance level (e.g., 'Did Not Yet Meet Expectations')
# - Year (STRING): Academic year when the test was taken (format: YYYY-YYYY)
#
# --- Generating 3 SQL Query Candidates ---
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.5, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating SQL candidate 1/3...
# Generating SQL candidate 2/3...
# Generating SQL candidate 3/3...
# SQL Writer generated 3 candidates.
# SQL Writer Total Generation Tokens: Input=3117, Output=351
#
# --- Validating Distinct SQL Query Candidates ---
# Attempting to validate 3 distinct candidates...
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.2, 'project': 'nw-ai-lab', 'location': 'us-central1'}
#
# Validating Distinct Candidate 1:
# Original Query:
#
# -- Determine the distribution of Annual Grade for each Grade Level Current
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS student_count
# FROM
#     `nw-ai-lab.illinois_2025_nw.iar_math`
# GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
# ORDER BY
#     Grade_Level_Current,
#     Annual_Grade;
#
# Attempt 1/3...
#   Result: PASSED (Dry Run)
#
# Validating Distinct Candidate 2:
# Original Query:
#
# -- Determine the distribution of Annual Grade for each Grade Level Current
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS Student_Count
# FROM
#     `nw-ai-lab.illinois_2025_nw.iar_math`
# GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
# ORDER BY
#     Grade_Level_Current,
#     Annual_Grade;
#
# Attempt 1/3...
#   Result: PASSED (Dry Run)
#
# Validating Distinct Candidate 3:
# Original Query:
#
# -- Determine the distribution of Annual Grade for each Grade Level Current.
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS StudentCount
#   FROM
#     `nw-ai-lab.illinois_2025_nw.iar_math`
#   GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
# UNION ALL
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS StudentCount
#   FROM
#     `nw-ai-lab.illinois_2025_nw.iar_ela`
#   GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
#
# Attempt 1/3...
#   Result: PASSED (Dry Run)
#
# SQL Validation complete. 3 distinct queries passed.
#
# --- Judging Passed SQL Queries ---
# Number of queries passed validation: 3
# Judging 3 passed queries...
# SQL Judge Raw Response:
# ```json
# {
#   "best_index": 3,
#   "reasoning": "Query 3 is the best because it combines data from both `iar_math` and `iar_ela` tables using `UNION ALL`, which is necessary to answer the question comprehensively. Queries 1 and 2 only consider the `iar_math` table, thus providing an incomplete answer. While the difference between queries 1 and 2 is only the column alias, query 3 is superior because it addresses the full scope of the question."
# }
# ```
# SQL Judge selected Candidate 3 from passed list.
# SQL Judge Tokens: Input=2422, Output=116
# Selected SQL Query (after judge):
#
# -- Determine the distribution of Annual Grade for each Grade Level Current.
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS StudentCount
#   FROM
#     `nw-ai-lab.illinois_2025_nw.iar_math`
#   GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
# UNION ALL
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS StudentCount
#   FROM
#     `nw-ai-lab.illinois_2025_nw.iar_ela`
#   GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
#
# SQL Judge Reasoning: Query 3 is the best because it combines data from both `iar_math` and `iar_ela` tables using `UNION ALL`, which is necessary to answer the question comprehensively. Queries 1 and 2 only consider the `iar_math` table, thus providing an incomplete answer. While the difference between queries 1 and 2 is only the column alias, query 3 is superior because it addresses the full scope of the question.
# --- Decision: After SQL Judge ---
# Proceeding to execute selected SQL.
#
# --- Executing Selected SQL Query ---
# Executing query:
#
# -- Determine the distribution of Annual Grade for each Grade Level Current.
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS StudentCount
#   FROM
#     `nw-ai-lab.illinois_2025_nw.iar_math`
#   GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
# UNION ALL
# SELECT
#     Grade_Level_Current,
#     Annual_Grade,
#     COUNT(*) AS StudentCount
#   FROM
#     `nw-ai-lab.illinois_2025_nw.iar_ela`
#   GROUP BY
#     Grade_Level_Current,
#     Annual_Grade
#
# Query executed successfully. DataFrame shape: (42, 3)
# --- Decision: After SQL Execution ---
# SQL Execution successful. Proceeding to BI Expert.
#
# --- Generating 3 BI Visualization Request Candidates ---
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.5, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating BI request candidate 1/3...
# Generating BI request candidate 2/3...
# Generating BI request candidate 3/3...
# Generated 3 total BI requests, 3 unique.
# BI Expert generated 3 candidates.
# BI Expert Total Generation Tokens: Input=3099, Output=481
#
# --- Decision: After BI Expert ---
# Generated 3 total BI requests, 3 unique.
# Proceeding to BI Judge node.
#
# --- Judging Distinct BI Requests ---
# Number of unique BI requests generated: 3
# Judging 3 unique BI requests...
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.1, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# BI Judge Raw Response:
# ```json
# {
#   "best_index": 1,
#   "reasoning": "All three requests suggest a grouped bar chart, which is appropriate for visualizing the distribution of Annual Grades within each Grade Level. They all also suggest a table with the raw data. Request 1 is slightly better because it explicitly states that the x-axis will represent the Grade Level Current and the y-axis will represent the StudentCount, and it clearly explains how the grouped bar chart will represent the data. The other requests are very similar, but request 1 is slightly more explicit."
# }
# ```
# BI Judge selected Candidate 1.
# BI Judge Tokens: Input=2113, Output=122
# Selected Visualization Request (after judge):
# To visualize the distribution of Annual Grade for students at each Grade Level Current, I recommend using a grouped bar chart. The x-axis will represent the Grade Level Current, and the y-axis will represent the StudentCount. Each group of bars will represent a Grade Level Current, and within each group, there will be a bar for each Annual Grade. This chart type is suitable because it allows for a direct comparison of the number of students with each Annual Grade within each Grade Level Current.
#
# Additionally, a table displaying Grade_Level_Current, Annual_Grade, and StudentCount will provide detailed information for each combination of grade level and annual grade. The table is useful for seeing the exact numbers and can be sorted by any of the columns to explore the data in more detail.
# BI Judge Reasoning: All three requests suggest a grouped bar chart, which is appropriate for visualizing the distribution of Annual Grades within each Grade Level. They all also suggest a table with the raw data. Request 1 is slightly better because it explicitly states that the x-axis will represent the Grade Level Current and the y-axis will represent the StudentCount, and it clearly explains how the grouped bar chart will represent the data. The other requests are very similar, but request 1 is slightly more explicit.
# --- Decision: After BI Judge ---
# Proceeding to Python Code Generation.
#
# --- Generating 3 Python Code Candidates ---
# visualization_request:  To visualize the distribution of Annual Grade for students at each Grade Level Current, I recommend using a grouped bar chart. The x-axis will represent the Grade Level Current, and the y-axis will represent the StudentCount. Each group of bars will represent a Grade Level Current, and within each group, there will be a bar for each Annual Grade. This chart type is suitable because it allows for a direct comparison of the number of students with each Annual Grade within each Grade Level Current.
#
# Additionally, a table displaying Grade_Level_Current, Annual_Grade, and StudentCount will provide detailed information for each combination of grade level and annual grade. The table is useful for seeing the exact numbers and can be sorted by any of the columns to explore the data in more detail.
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.3, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating Python code candidate 1/3...
# Generating Python code candidate 2/3...
# Generating Python code candidate 3/3...
# Generated 3 total Python codes, 3 unique.
# Python Generator generated 3 candidates.
# Python Generator Total Generation Tokens: Input=1662, Output=1083
#
# --- Decision: After Python Code Generator ---
# Generated 3 total Python codes, 3 unique.
# Proceeding to Python Judge node.
#
# --- Judging Distinct Python Code Candidates ---
# Number of unique Python codes generated: 3
# Judging 3 unique Python codes...
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.1, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Python Judge Raw Response:
# ```json
# {
#   "best_index": 1,
#   "reasoning": "Code snippet 1 is the best because it defines a function that takes a DataFrame as input and returns a Plotly figure and a Pandas DataFrame, adhering to the instructions. It also includes axis labels and a legend title, improving the chart's readability. It also handles the case where the input DataFrame is empty. Snippets 2 and 3 include example usage that instantiates a DataFrame and calls the function, which is not desired."
# }
# ```
# Python Judge selected Candidate 1.
# Python Judge Tokens: Input=3299, Output=113
# Selected Python Code (after judge):
# ```python
#
# import pandas as pd
# import plotly.express as px
#
# def create_grouped_bar_chart_and_table(df):
#     """
#     Generates a grouped bar chart and a Pandas DataFrame from the input DataFrame.
#
#     Args:
#         df (pd.DataFrame): Input DataFrame with columns 'Grade_Level_Current', 'Annual_Grade', and 'StudentCount'.
#
#     Returns:
#         tuple: A tuple containing the Plotly figure and the Pandas DataFrame.
#     """
#
#     df_viz = df.copy()
#
#     if df_viz.empty:
#         print("No data available.")
#         fig = px.bar()  # Return an empty figure
#         return fig, df_viz
#
#     # Create the grouped bar chart
#     fig = px.bar(
#         df_viz,
#         x='Grade_Level_Current',
#         y='StudentCount',
#         color='Annual_Grade',
#         barmode='group',
#         labels={'Grade_Level_Current': 'Grade Level Current', 'StudentCount': 'Student Count', 'Annual_Grade': 'Annual Grade'},
#         title='Student Count by Grade Level and Annual Grade'
#     )
#
#     fig.update_layout(
#         xaxis_title='Grade Level Current',
#         yaxis_title='Student Count',
#         legend_title='Annual Grade'
#     )
#
#     return fig, df_viz
#
# # Example usage (assuming you have a DataFrame named 'df'):
# # fig, df_viz = create_grouped_bar_chart_and_table(df)
#
# ```
# Python Judge Reasoning: Code snippet 1 is the best because it defines a function that takes a DataFrame as input and returns a Plotly figure and a Pandas DataFrame, adhering to the instructions. It also includes axis labels and a legend title, improving the chart's readability. It also handles the case where the input DataFrame is empty. Snippets 2 and 3 include example usage that instantiates a DataFrame and calls the function, which is not desired.
# --- Decision: After Python Judge ---
# Proceeding to Python Code Validation.
#
#
# ### Validating data visualization code:
# result: Pass
#
# --- Generating 3 Insights Candidate(s) ---
# Insights Generator using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.4, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating Insights Candidate 1/3...
# Generating Insights Candidate 2/3...
# Generating Insights Candidate 3/3...
# Insights Generator produced 3 candidates.
# Insights Generator Total Tokens: Input=639459, Output=1033
#
# --- Decision: After Insights Generator ---
# Multiple unique insights generated. Proceeding to Insights Judge node.
#
# --- Judging Distinct Insight Candidates ---
# Number of unique insight texts to judge: 3
# Insights Judge using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.4, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Invoking Insights Judge LLM...
# Insights Judge Raw Response:
# ```json
# {
#   "best_index": 3,
#   "reasoning": "Insights text 3 is the strongest because it offers the most actionable MTSS-aligned recommendations directly supported by the data. It suggests cross-curricular projects, peer tutoring across grade levels, and a recognition program, all of which are practical and aligned with the observed correlations. The other texts also have good points, but their recommendations are either less specific or less directly tied to the data's implications for immediate action within an MTSS framework. The inclusion of 'consistent high performance' in the recognition program is also a good way to promote equity."
# }
# ```
# Insights Judge selected Candidate 3.
# Insights Judge Tokens: Input=213276, Output=134
# Selected Insight (after judge): Okay, here's an analysis of the provided data and contexts, focusing on actionable recommendations.
#
# **Blurb:** The data suggests a strong correlation between current grade level and annual grades in ...
# Insights Judge Reasoning: Insights text 3 is the strongest because it offers the most actionable MTSS-aligned recommendations directly supported by the data. It suggests cross-curricular projects, peer tutoring across grade levels, and a recognition program, all of which are practical and aligned with the observed correlations. The other texts also have good points, but their recommendations are either less specific or less directly tied to the data's implications for immediate action within an MTSS framework. The inclusion of 'consistent high performance' in the recognition program is also a good way to promote equity.
# 67.2346465587616

# %%
if 'python_code_store_variables_dict' in final_state and 'df' in final_state['python_code_store_variables_dict']:
  print(final_state['python_code_store_variables_dict']['df_viz'])
else:
  print("DataFrame does not exist.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-a0f29b2665dc> in <cell line: 0>()
#       1 if 'python_code_store_variables_dict' in final_state and 'df' in final_state['python_code_store_variables_dict']:
# ----> 2   print(final_state['python_code_store_variables_dict']['df_viz'])
#       3 else:
#       4   print("DataFrame does not exist.")
#
# KeyError: 'df_viz'

# %%
if 'python_code_store_variables_dict' in final_state and 'fig' in final_state['python_code_store_variables_dict']:
  final_state['python_code_store_variables_dict']['fig'].show()
else:
  print("No visualization was generated.")

# %%
final_state['generated_insights']
# Out:
# "Here's an analysis of the provided data, focusing on actionable insights and MTSS alignment:\n\n**Blurb:** The data highlights a correlation between current grade level and annual grades, with some homerooms showing stronger associations than others. Additionally, performance in English and Math are correlated.\n\n**Key Observations:**\n\n*   Current grade level strongly correlates with annual grades in both English and Math (0.802-0.842).\n*   Test scores in English and Math show a moderate positive correlation (0.611).\n*   Specific homerooms (e.g., I203, I204 in English and I210 in Math) show some correlation with annual grades (0.54-0.62), suggesting homeroom environment may influence performance.\n*   Students who partially meet expectations in one subject are likely to struggle in other subjects.\n\n**Suggestions (From the CORRELATION MATRIX SUMMARY):**\n\n*   Test Grades (Math) is correlated with Test Grades (English), ensuring a student does well in one will help them overall.\n*   Participation is correlated and linked to better grades.\n*   Homerooms that do well in one subject are not guaranteed to do well in every subject.\n\n**MTSS-Aligned Recommendations:**\n\n*   For all students, implement cross-curricular activities that reinforce skills in both English and Math, capitalizing on the observed correlation between the two subjects.\n*   For students in homerooms I203, I204 (English) and I210 (Math), foster a more supportive and engaging classroom environment, as these homerooms show a stronger correlation between the homeroom and annual grades.\n*   Provide targeted support to students who are partially meeting expectations in either English or Math, as these students are likely to need support in both subjects.\n\nThese recommendations are directly supported by the provided data and align with the MTSS framework by focusing on school-wide strategies, targeted interventions, and intensive supports based on student needs."

# %%
from ast import mod
import importlib # Import the importlib module
import prompts
import workflow
import time
importlib.reload(prompts) # This reloads your main workflow.py
importlib.reload(workflow) # This reloads your main workflow.py

questions = ["""What is the distribution of (Annual Grade) for students at each (Grade Level Current)?""",
"""How does the (Test Grade) correlate with the (Test Scaled Score) across different (Subject Category)?""",
"""What is the average (Student Growth Percentile) for students in each (Current Homeroom), and are there significant differences between homerooms?"""]

questions = ["""What is the distribution of (Annual Grade) for students at each (Grade Level Current)?""",
"""How does the (Test Grade) correlate with the (Test Scaled Score) across different (Subject Category)?""",
"""What is the average (Student Growth Percentile) for students in each (Current Homeroom), and are there significant differences between homerooms?""",
"""Which (Tested School) has the highest average (Test Scaled Score), and how does this compare to the average (Test Scaled Score) of students at their (Current School)?""",
"""Are there any specific (Product) types that are associated with higher or lower (Test Scaled Score) results?""",
"""How does the (Test Primary Result Code) vary across different (Subject Category) and (Grade Level Current)?""",
"""What is the trend of (Test Scaled Score) over the (Year) for students in a specific (Grade Level Current)?""",
"""Can we identify students with a low (Annual Grade) but high (Student Growth Percentile), and what are their characteristics in terms of (Current Homeroom) and (Subject Category)?""",
"""What is the relationship between (Annual Grade) and (Test Grade) for students at different (Grade Level Current)?""",
"""How many students are associated with each (Product) and what is the average (Test Scaled Score) for each (Product)?""",
"""IAR Math""",
"""How does the (Test Scaled Score) correlate with the (Annual Grade) for students across different (Grade Level Current)?""",
"""What is the distribution of (Student Growth Percentile) within each (Subject Category), and are there any notable differences?""",
"""Are there specific (Tested School) or (Current School) locations where students tend to have higher or lower (Test Scaled Score) averages?""",
"""How does the (Product) used by students relate to their (Test Grade) and (Student Growth Percentile)?""",
"""What is the average (Test Scaled Score) for each (Grade Level Current), and how does this trend change over the (Year)?""",
"""Are there any patterns between (Current Homeroom) and (Test Primary Result Code) that might indicate specific teaching strategies or classroom environments that are more effective?""",
"""Which students, identified by (Student Name) and (Student ID), have shown the most significant (Student Growth Percentile) from one (Year) to the next?""",
"""How does the (Test Grade) compare to the (Annual Grade) for students, and are there any students who consistently perform differently on tests versus their overall grades?""",
"""What are the most frequent (Test Primary Result Code) values, and how do they vary across different (Subject Category)?""",
"""Can we identify any relationships between the (Current School) and the (Product) used by students, and does this have any impact on (Test Scaled Score)?"""]

potential_models = [
    #"gemini-2.0-flash-lite",
    "gemini-2.0-flash"
    #,"gemini-2.5-flash-preview-04-17"
    #,"gemini-2.5-pro-preview-05-06"
    ]


#questions = ["""What is the distribution of (Annual Grade) for students at each (Grade Level Current)?"""]
#potential_models = ["gemini-2.0-flash"]

model_dict = {}

for model in potential_models:
    total_cost = 0
    total_input_tokens = 0
    total_output_tokens = 0
    total_runs = 0
    total_run_time = 0
    if model == "gemini-2.5-pro-preview-05-06" and total_runs >= 5:
        break
    for question in questions:
        try:
            start_time = time.time()
            final_state = workflow.run_workflow(question,
                                    user_stories_text=user_stories_text_content,
                                    mtss_docs_text=mtss_docs_text_content,
                                    correlations_text=correlations_string_summary,

                                    sql_writer_n_runs=3,
                                    bi_expert_n_runs=3,
                                    py_gen_n_runs=3,
                                    insights_n_runs=3,

                                    llm_sql_writer_model_name=model,
                                    llm_sql_validator_model_name=model,
                                    llm_sql_judge_model_name=model,
                                    llm_bi_expert_model_name=model,
                                    llm_bi_judge_model_name=model,
                                    llm_python_writer_model_name=model,
                                    llm_python_validator_model_name=model,
                                    llm_python_judge_model_name=model,
                                    llm_insights_generator_model_name=model,
                                    llm_insights_judge_model_name=model)
            run_time = time.time() - start_time
            total_run_time += run_time
            run_cost, input_tokens, output_tokens = calculate_llm_cost(final_state)
            total_cost += run_cost
            total_input_tokens += input_tokens
            total_output_tokens += output_tokens
            total_runs += 1
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
    model_dict[model] = [total_cost, total_input_tokens, total_output_tokens, total_runs, total_run_time]

for model in potential_models:
    print(f"Model: {model}")
    print(f"Total cost: {model_dict[model][0]}")
    print(f"Total input tokens: {model_dict[model][1]}")
    print(f"Total output tokens: {model_dict[model][2]}")
    print(f"Total runs: {model_dict[model][3]}")
    print(f"Average run time: {model_dict[model][4] / model_dict[model][3]}")
    print(f"Average cost per run: {model_dict[model][0] / model_dict[model][3]}")
    print(f"Average input tokens per run: {model_dict[model][1] / model_dict[model][3]}")
    print(f"Average output tokens per run: {model_dict[model][2] / model_dict[model][3]}")
    print("")
# Out:
# Streaming output truncated to the last 5000 lines.
#                                ' \xa0 implementation\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 the\t\r'
#                                ' \xa0 purpose\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0\n'
#                                'developing\t\r'
#                                ' \xa0specific\t\r'
#                                ' \xa0action\t\r'
#                                ' \xa0plans\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0increase\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0levels.\t\r'
#                                ' \xa0\n'
#                                '22. Priority\t\r'
#                                ' \xa0learning\t\r'
#                                ' \xa0standards\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0curriculum\t\r'
#                                ' \xa0standards\t\r'
#                                ' \xa0that\t\r'
#                                ' \xa0define\t\r'
#                                ' \xa0what\t\r'
#                                ' \xa0students\t\r'
#                                ' \xa0should\t\r'
#                                ' \xa0know\t\r'
#                                ' \xa0\n'
#                                'and\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 able\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 do\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 a\t\r'
#                                ' \xa0 given\t\r'
#                                ' \xa0 content\t\r'
#                                ' \xa0 area\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 grade\t\r'
#                                ' \xa0 level\t\r'
#                                ' \xa0 (e.g.,\t\r'
#                                ' \xa0 Common\t\r'
#                                ' \xa0 Core\t\r'
#                                ' \xa0 State\t\r'
#                                ' \xa0\n'
#                                'Standards;\t\r'
#                                ' \xa0state\t\r'
#                                ' \xa0specific\t\r'
#                                ' \xa0standards,\t\r'
#                                ' \xa0Social-\xad‐Emotional\t\r'
#                                ' \xa0Learning\t\r'
#                                ' \xa0Standards).\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '23. Expectations\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0often\t\r'
#                                ' \xa0include\t\r'
#                                ' \xa0elements\t\r'
#                                ' \xa0related\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0routine\t\r'
#                                ' \xa0(e.g.,\t\r'
#                                ' \xa0\n'
#                                'whole-\xad‐group,\t\r'
#                                ' \xa0 small-\xad‐group,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 independent\t\r'
#                                ' \xa0 practice),\t\r'
#                                ' \xa0 amount\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 time\t\r'
#                                ' \xa0 dedicated\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0\n'
#                                'instruction,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0which\t\r'
#                                ' \xa0evidence-\xad‐based\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0strategies\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0used.\t\r'
#                                ' \xa0\n'
#                                '24. Both\t\r'
#                                ' \xa0 statewide\t\r'
#                                ' \xa0 assessments\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 formative\t\r'
#                                ' \xa0 assessments\t\r'
#                                ' \xa0 administered\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 all\t\r'
#                                ' \xa0 students\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0\n'
#                                'important\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 identify\t\r'
#                                ' \xa0 so\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 expectations\t\r'
#                                ' \xa0 for\t\r'
#                                ' \xa0 the\t\r'
#                                ' \xa0 data\t\r'
#                                ' \xa0 needed\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 inform\t\r'
#                                ' \xa0 decisions\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0\n'
#                                'consistent.\t\r'
#                                ' \xa0\n'
#                                '\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                'SAM\t\r'
#                                ' \xa0Version\t\r'
#                                ' \xa02.0\t\r'
#                                ' \xa0(October\t\r'
#                                ' \xa02015)\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0-\xad‐\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0Page\t\r'
#                                ' \xa04\t\r'
#                                ' \xa0\n'
#                                '25. Structured\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0behavioral\t\r'
#                                ' \xa0expectations\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0emotional\t\r'
#                                ' \xa0skills\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0provided\t\r'
#                                ' \xa0\n'
#                                'to\t\r'
#                                ' \xa0 all\t\r'
#                                ' \xa0 students.\t\r'
#                                ' \xa0 Classroom\t\r'
#                                ' \xa0 routines\t\r'
#                                ' \xa0 include\t\r'
#                                ' \xa0 social\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 emotional\t\r'
#                                ' \xa0 learning\t\r'
#                                ' \xa0 principles\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'classroom\t\r'
#                                ' \xa0 management\t\r'
#                                ' \xa0 strategies\t\r'
#                                ' \xa0 embedded\t\r'
#                                ' \xa0 into\t\r'
#                                ' \xa0 instruction.\t\r'
#                                ' \xa0 School\t\r'
#                                ' \xa0 climate\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'environments\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0well-\xad‐being.\t\r'
#                                ' \xa0A\t\r'
#                                ' \xa0small\t\r'
#                                ' \xa0number\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0clearly\t\r'
#                                ' \xa0defined\t\r'
#                                ' \xa0school-\xad‐wide\t\r'
#                                ' \xa0\n'
#                                'expectations\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 positively\t\r'
#                                ' \xa0 stated\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 a\t\r'
#                                ' \xa0 foundational\t\r'
#                                ' \xa0 element\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 Tier\t\r'
#                                ' \xa0 1\t\r'
#                                ' \xa0 school-\xad‐wide\t\r'
#                                ' \xa0\n'
#                                'behavior\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0system.\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '26. School-\xad‐wide\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0 behavior\t\r'
#                                ' \xa0 data\t\r'
#                                ' \xa0 may\t\r'
#                                ' \xa0 include\t\r'
#                                ' \xa0 Office\t\r'
#                                ' \xa0 Discipline\t\r'
#                                ' \xa0 Referrals,\t\r'
#                                ' \xa0 In-\xad‐\n'
#                                'School\t\r'
#                                ' \xa0 Suspensions,\t\r'
#                                ' \xa0 Out-\xad‐of-\xad‐School\t\r'
#                                ' \xa0 Suspensions,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0 screening\t\r'
#                                ' \xa0 data\t\r'
#                                ' \xa0\n'
#                                'sources\t\r'
#                                ' \xa0used\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0examine\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0effectiveness\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0behavior\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0supports.\t\r'
#                                ' \xa0\n'
#                                '27. Tier\t\r'
#                                ' \xa0 2\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 should\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 aligned\t\r'
#                                ' \xa0 with\t\r'
#                                ' \xa0 Tier\t\r'
#                                ' \xa0 1\t\r'
#                                ' \xa0 instructional\t\r'
#                                ' \xa0 goals\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 expectations,\t\r'
#                                ' \xa0\n'
#                                'address\t\r'
#                                ' \xa0 high-\xad‐probability\t\r'
#                                ' \xa0 barriers\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 achieving\t\r'
#                                ' \xa0 instructional\t\r'
#                                ' \xa0 goals\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 expectations,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0\n'
#                                'include\t\r'
#                                ' \xa0assessments\t\r'
#                                ' \xa0which\t\r'
#                                ' \xa0measure\t\r'
#                                ' \xa0specific\t\r'
#                                ' \xa0skills,\t\r'
#                                ' \xa0general\t\r'
#                                ' \xa0outcomes,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0progress.\t\r'
#                                ' \xa0\n'
#                                '28. Tier\t\r'
#                                ' \xa0 2\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 should\t\r'
#                                ' \xa0 be\t\r'
#                                ' \xa0 aligned\t\r'
#                                ' \xa0 with\t\r'
#                                ' \xa0 school-\xad‐wide\t\r'
#                                ' \xa0 behavior\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0\n'
#                                'expectations,\t\r'
#                                ' \xa0address\t\r'
#                                ' \xa0high-\xad‐probability\t\r'
#                                ' \xa0barriers\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0meeting\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0goals\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0\n'
#                                'well-\xad‐being,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 include\t\r'
#                                ' \xa0 assessments\t\r'
#                                ' \xa0 that\t\r'
#                                ' \xa0 monitor\t\r'
#                                ' \xa0 student\t\r'
#                                ' \xa0 discipline\t\r'
#                                ' \xa0 incidents,\t\r'
#                                ' \xa0 social-\xad‐\n'
#                                'emotional\t\r'
#                                ' \xa0skills,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0well-\xad‐being.\t\r'
#                                ' \xa0\n'
#                                '29. Tier\t\r'
#                                ' \xa0 3\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 generally\t\r'
#                                ' \xa0 provide\t\r'
#                                ' \xa0 increased\t\r'
#                                ' \xa0 exposure\t\r'
#                                ' \xa0 (time\t\r'
#                                ' \xa0 in\t\r'
#                                ' \xa0 minutes)\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 quality\t\r'
#                                ' \xa0\n'
#                                'instruction\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0intervention,\t\r'
#                                ' \xa0more\t\r'
#                                ' \xa0focused\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0matched\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0need,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0smaller\t\r'
#                                ' \xa0\n'
#                                'groupings.\t\r'
#                                ' \xa0Additionally,\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa03\t\r'
#                                ' \xa0interventions\t\r'
#                                ' \xa0often\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0developed\t\r'
#                                ' \xa0during\t\r'
#                                ' \xa0individual\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0\n'
#                                'focused\t\r'
#                                ' \xa0 problem-\xad‐solving\t\r'
#                                ' \xa0 sessions.\t\r'
#                                ' \xa0 Importantly,\t\r'
#                                ' \xa0 Tier\t\r'
#                                ' \xa0 3\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 focused\t\r'
#                                ' \xa0 on\t\r'
#                                ' \xa0 academic\t\r'
#                                ' \xa0\n'
#                                'issues\t\r'
#                                ' \xa0should\t\r'
#                                ' \xa0be\t\r'
#                                ' \xa0linked\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa02\t\r'
#                                ' \xa0instructional\t\r'
#                                ' \xa0content\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0processes\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0also\t\r'
#                                ' \xa0should\t\r'
#                                ' \xa0\n'
#                                'consider\t\r'
#                                ' \xa0what\t\r'
#                                ' \xa0behavioral\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0supports\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0needed\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0success.\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '30. Tier\t\r'
#                                ' \xa0 3\t\r'
#                                ' \xa0 interventions\t\r'
#                                ' \xa0 are\t\r'
#                                ' \xa0 matched\t\r'
#                                ' \xa0 to\t\r'
#                                ' \xa0 a\t\r'
#                                ' \xa0 student’s\t\r'
#                                ' \xa0 specific\t\r'
#                                ' \xa0 behavior\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 social-\xad‐emotional\t\r'
#                                ' \xa0\n'
#                                'needs\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0ensure\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0has\t\r'
#                                ' \xa0access\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0Tier\t\r'
#                                ' \xa02\t\r'
#                                ' \xa0supports.\t\r'
#                                ' \xa0For\t\r'
#                                ' \xa0a\t\r'
#                                ' \xa0few\t\r'
#                                ' \xa0students\t\r'
#                                ' \xa0\n'
#                                'with\t\r'
#                                ' \xa0complex\t\r'
#                                ' \xa0needs,\t\r'
#                                ' \xa0individualized\t\r'
#                                ' \xa0interventions\t\r'
#                                ' \xa0may\t\r'
#                                ' \xa0involve\t\r'
#                                ' \xa0wraparound\t\r'
#                                ' \xa0supports\t\r'
#                                ' \xa0across\t\r'
#                                ' \xa0\n'
#                                'systems\t\r'
#                                ' \xa0(e.g.,\t\r'
#                                ' \xa0mental\t\r'
#                                ' \xa0health,\t\r'
#                                ' \xa0education,\t\r'
#                                ' \xa0medical,\t\r'
#                                ' \xa0family,\t\r'
#                                ' \xa0etc.).\t\r'
#                                ' \xa0Individualized\t\r'
#                                ' \xa0interventions\t\r'
#                                ' \xa0\n'
#                                'include\t\r'
#                                ' \xa0 specific\t\r'
#                                ' \xa0 prevention\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 consequence-\xad‐based\t\r'
#                                ' \xa0 strategies\t\r'
#                                ' \xa0 based\t\r'
#                                ' \xa0 on\t\r'
#                                ' \xa0 assessment\t\r'
#                                ' \xa0\n'
#                                'information\t\r'
#                                ' \xa0(i.e.,\t\r'
#                                ' \xa0Functional\t\r'
#                                ' \xa0Behavior\t\r'
#                                ' \xa0Assessment),\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0may\t\r'
#                                ' \xa0include\t\r'
#                                ' \xa0modifications\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0\n'
#                                'classroom\t\r'
#                                ' \xa0 environment\t\r'
#                                ' \xa0 or\t\r'
#                                ' \xa0 instruction,\t\r'
#                                ' \xa0 teaching\t\r'
#                                ' \xa0 new\t\r'
#                                ' \xa0 skills,\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 reinforcement\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 desired\t\r'
#                                ' \xa0\n'
#                                'behaviors\t\r'
#                                ' \xa0as\t\r'
#                                ' \xa0well\t\r'
#                                ' \xa0as\t\r'
#                                ' \xa0a\t\r'
#                                ' \xa0range\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0supports\t\r'
#                                ' \xa0such\t\r'
#                                ' \xa0as\t\r'
#                                ' \xa0mental\t\r'
#                                ' \xa0health\t\r'
#                                ' \xa0services.\t\r'
#                                ' \xa0\n'
#                                '31. District\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0states\t\r'
#                                ' \xa0typically\t\r'
#                                ' \xa0create\t\r'
#                                ' \xa0or\t\r'
#                                ' \xa0adopt\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0management\t\r'
#                                ' \xa0systems.\t\r'
#                                ' \xa0They\t\r'
#                                ' \xa0also\t\r'
#                                ' \xa0specify\t\r'
#                                ' \xa0\n'
#                                'access\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 use\t\r'
#                                ' \xa0 requirements.\t\r'
#                                ' \xa0 School\t\r'
#                                ' \xa0 leaders\t\r'
#                                ' \xa0 should\t\r'
#                                ' \xa0 coordinate\t\r'
#                                ' \xa0 with\t\r'
#                                ' \xa0 district\t\r'
#                                ' \xa0 and\t\r'
#                                ' \xa0 state\t\r'
#                                ' \xa0\n'
#                                'leaders\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0understand\t\r'
#                                ' \xa0requirements\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0establish\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0communicate\t\r'
#                                ' \xa0procedures\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0using\t\r'
#                                ' \xa0\n'
#                                'the\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0system\t\r'
#                                ' \xa0at\t\r'
#                                ' \xa0their\t\r'
#                                ' \xa0school.\t\r'
#                                ' \xa0Quality\t\r'
#                                ' \xa0indicators\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0management\t\r'
#                                ' \xa0systems\t\r'
#                                ' \xa0include:\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                'real-\xad‐time\t\r'
#                                ' \xa0relevant\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0academic,\t\r'
#                                ' \xa0behavior,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0content,\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0ability\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0\n'
#                                'graphically\t\r'
#                                ' \xa0 represent\t\r'
#                                ' \xa0 data,\t\r'
#                                ' \xa0 provision\t\r'
#                                ' \xa0 of\t\r'
#                                ' \xa0 tiered\t\r'
#                                ' \xa0 intervention\t\r'
#                                ' \xa0 data,\t\r'
#                                ' \xa0 integrated\t\r'
#                                ' \xa0 academic,\t\r'
#                                ' \xa0\n'
#                                'behavior,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0social-\xad‐emotional\t\r'
#                                ' \xa0data,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0customizable\t\r'
#                                ' \xa0at\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0school\t\r'
#                                ' \xa0level.\t\r'
#                                ' \xa0\n'
#                                '\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                'SAM\t\r'
#                                ' \xa0Version\t\r'
#                                ' \xa02.0\t\r'
#                                ' \xa0(October\t\r'
#                                ' \xa02015)\t\r'
#                                ' \xa0\n'
#                                'SAM\t\r'
#                                ' \xa0Scoring\t\r'
#                                ' \xa0Sheet\t\r'
#                                ' \xa0\n'
#                                '\t\r'
#                                ' \xa0\n'
#                                'THIS\t\r'
#                                ' \xa0SCORING\t\r'
#                                ' \xa0SHEET\t\r'
#                                ' \xa0HAS\t\r'
#                                ' \xa0ABBREVIATED\t\r'
#                                ' \xa0LANGUAGE\t\r'
#                                ' \xa0AND\t\r'
#                                ' \xa0SHOULD\t\r'
#                                ' \xa0ONLY\t\r'
#                                ' \xa0BE\t\r'
#                                ' \xa0USED\t\r'
#                                ' \xa0TO\t\r'
#                                ' \xa0RECORD\t\r'
#                                ' \xa0AND\t\r'
#                                ' \xa0DISPLAY\t\r'
#                                ' \xa0RESPONSES\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                'Rate\t\r'
#                                ' \xa0each\t\r'
#                                ' \xa0item\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0a\t\r'
#                                ' \xa0scale\t\r'
#                                ' \xa0from\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0(0\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Not\t\r'
#                                ' \xa0Started;\t\r'
#                                ' \xa01\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Emerging/Developing;\t\r'
#                                ' \xa02\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Operationalizing;\t\r'
#                                ' \xa03\t\r'
#                                ' \xa0=\t\r'
#                                ' \xa0Optimizing)\t\r'
#                                ' \xa0\n'
#                                '1.\t\r'
#                                ' \xa0Leadership\t\r'
#                                ' \xa0Domain\t\r'
#                                ' \xa0(Items\t\r'
#                                ' \xa01-\xad‐5)\t\r'
#                                ' \xa0\n'
#                                'Rating\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0\n'
#                                '1.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0principal\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0actively\t\r'
#                                ' \xa0involved\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '2.\t\r'
#                                ' \xa0A\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0established\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '3.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0actively\t\r'
#                                ' \xa0engages\t\r'
#                                ' \xa0in\t\r'
#                                ' \xa0ongoing\t\r'
#                                ' \xa0professional\t\r'
#                                ' \xa0development\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '4.\t\r'
#                                ' \xa0A\t\r'
#                                ' \xa0strategic\t\r'
#                                ' \xa0plan\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0developed\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '5.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0actively\t\r'
#                                ' \xa0facilitating\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '2.\t\r'
#                                ' \xa0Building\t\r'
#                                ' \xa0the\t\r'
#                                ' \xa0Capacity/Infrastructure\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0Implementation\t\r'
#                                ' \xa0Domain\t\r'
#                                ' \xa0(Items\t\r'
#                                ' \xa06-\xad‐16)\t\r'
#                                ' \xa0\n'
#                                'Rating\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0\n'
#                                '6.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0critical\t\r'
#                                ' \xa0elements\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0defined\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0understood\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '7.\t\r'
#                                ' \xa0Professional\t\r'
#                                ' \xa0development\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0coaching\t\r'
#                                ' \xa0provided\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0staff\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '8.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0facilitates\t\r'
#                                ' \xa0PD\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0data-\xad‐based\t\r'
#                                ' \xa0problem-\xad‐solving\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '9.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0leadership\t\r'
#                                ' \xa0team\t\r'
#                                ' \xa0facilitates\t\r'
#                                ' \xa0PD\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0multi-\xad‐tiered\t\r'
#                                ' \xa0instruction\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0intervention\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '10.\t\r'
#                                ' \xa0Coaching\t\r'
#                                ' \xa0is\t\r'
#                                ' \xa0used\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '11.\t\r'
#                                ' \xa0Schedules\t\r'
#                                ' \xa0provide\t\r'
#                                ' \xa0adequate\t\r'
#                                ' \xa0time\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0training\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0coaching\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '12.\t\r'
#                                ' \xa0Schedules\t\r'
#                                ' \xa0provide\t\r'
#                                ' \xa0adequate\t\r'
#                                ' \xa0time\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0administer\t\r'
#                                ' \xa0assessments\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '13.\t\r'
#                                ' \xa0Schedules\t\r'
#                                ' \xa0provide\t\r'
#                                ' \xa0adequate\t\r'
#                                ' \xa0time\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0multiple\t\r'
#                                ' \xa0tiers\t\r'
#                                ' \xa0of\t\r'
#                                ' \xa0instruction/interventions\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '14.\t\r'
#                                ' \xa0Schedules\t\r'
#                                ' \xa0provide\t\r'
#                                ' \xa0adequate\t\r'
#                                ' \xa0time\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0data-\xad‐based\t\r'
#                                ' \xa0problem-\xad‐solving\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '15.\t\r'
#                                ' \xa0Processes,\t\r'
#                                ' \xa0procedures,\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0decision-\xad‐rules\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0established\t\r'
#                                ' \xa0for\t\r'
#                                ' \xa0DBPS\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '16.\t\r'
#                                ' \xa0Resources\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0implementation\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0identified\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0allocated\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '3.\t\r'
#                                ' \xa0Communication\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0Collaboration\t\r'
#                                ' \xa0Domain\t\r'
#                                ' \xa0(Items\t\r'
#                                ' \xa017-\xad‐20)\t\r'
#                                ' \xa0\n'
#                                'Rating\t\r'
#                                ' \xa00-\xad‐3\t\r'
#                                ' \xa0\n'
#                                '17.\t\r'
#                                ' \xa0Staff\t\r'
#                                ' \xa0have\t\r'
#                                ' \xa0consensus\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0engage\t\r'
#                                ' \xa0in\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0Implementation\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '18.\t\r'
#                                ' \xa0Staff\t\r'
#                                ' \xa0are\t\r'
#                                ' \xa0provided\t\r'
#                                ' \xa0data\t\r'
#                                ' \xa0on\t\r'
#                                ' \xa0MTSS\t\r'
#                                ' \xa0fidelity\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0student\t\r'
#                                ' \xa0outcomes\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '19.\t\r'
#                                ' \xa0The\t\r'
#                                ' \xa0infrastructure\t\r'
#                                ' \xa0exists\t\r'
#                                ' \xa0to\t\r'
#                                ' \xa0support\t\r'
#                                ' \xa0family\t\r'
#                                ' \xa0and\t\r'
#                                ' \xa0community\t\r'
#                                ' \xa0engagement\t\r'
#                                ' \xa0\t\r'
#                                ' \xa0\n'
#                                '0\t\r'
#                                ' \xa0\n'
#                                '1\t\r'
#                                ' \xa0\n'
#                                '2\t\r'
#                                ' \xa0\n'
#                                '3\t\r'
#                                ' \xa0\n'
#                                '20.\t\r'
# ...
# -- By examining the output, we can identify if certain schools or products are associated with higher or lower average test scores.
# -- A significant difference in average scores between different schools or products might suggest a relationship.
#
# Attempt 1/3...
#   Result: PASSED (Dry Run)
#
# Validating Distinct Candidate 3:
# Original Query:
#
# -- Analyze the relationship between Current School, Product, and Test Scaled Score
#
# WITH
#   SchoolProductScores AS (
#     -- Combine ELA and Math data to analyze all test scores
#     SELECT
#       Current_School,
#       Product,
#       Test_Scaled_Score
#     FROM
#       `nw-ai-lab.illinois_2025_nw.iar_ela`
#     UNION ALL
#     SELECT
#       Current_School,
#       Product,
#       Test_Scaled_Score
#     FROM
#       `nw-ai-lab.illinois_2025_nw.iar_math`
#   ),
#   -- Calculate average test scores for each school and product combination
#   AvgScores AS (
#     SELECT
#       Current_School,
#       Product,
#       AVG(Test_Scaled_Score) AS Avg_Test_Scaled_Score,
#       COUNT(*) AS Number_of_Tests
#     FROM
#       SchoolProductScores
#     GROUP BY
#       Current_School,
#       Product
#   )
# -- Final SELECT statement to display the results
# SELECT
#   Current_School,
#   Product,
#   Avg_Test_Scaled_Score,
#   Number_of_Tests
# FROM
#   AvgScores
# ORDER BY
#   Current_School,
#   Product;
#
# Attempt 1/3...
#   Result: PASSED (Dry Run)
#
# SQL Validation complete. 3 distinct queries passed.
#
# --- Judging Passed SQL Queries ---
# Number of queries passed validation: 3
# Judging 3 passed queries...
# SQL Judge Raw Response:
# ```json
# {
#   "best_index": 3,
#   "reasoning": "Query 3 is the best because it uses a CTE (Common Table Expression) to combine the data from the two tables and then calculates the average test scores. This approach is more readable and potentially more efficient than the UNION ALL approach used in Queries 1 and 2, especially as the number of tables grows. While Queries 1 and 2 are functionally correct, Query 3's structure is cleaner and easier to understand, making it the preferred choice for maintainability and potential performance benefits."
# }
# ```
# SQL Judge selected Candidate 3 from passed list.
# SQL Judge Tokens: Input=3600, Output=125
# Selected SQL Query (after judge):
#
# -- Analyze the relationship between Current School, Product, and Test Scaled Score
#
# WITH
#   SchoolProductScores AS (
#     -- Combine ELA and Math data to analyze all test scores
#     SELECT
#       Current_School,
#       Product,
#       Test_Scaled_Score
#     FROM
#       `nw-ai-lab.illinois_2025_nw.iar_ela`
#     UNION ALL
#     SELECT
#       Current_School,
#       Product,
#       Test_Scaled_Score
#     FROM
#       `nw-ai-lab.illinois_2025_nw.iar_math`
#   ),
#   -- Calculate average test scores for each school and product combination
#   AvgScores AS (
#     SELECT
#       Current_School,
#       Product,
#       AVG(Test_Scaled_Score) AS Avg_Test_Scaled_Score,
#       COUNT(*) AS Number_of_Tests
#     FROM
#       SchoolProductScores
#     GROUP BY
#       Current_School,
#       Product
#   )
# -- Final SELECT statement to display the results
# SELECT
#   Current_School,
#   Product,
#   Avg_Test_Scaled_Score,
#   Number_of_Tests
# FROM
#   AvgScores
# ORDER BY
#   Current_School,
#   Product;
#
# SQL Judge Reasoning: Query 3 is the best because it uses a CTE (Common Table Expression) to combine the data from the two tables and then calculates the average test scores. This approach is more readable and potentially more efficient than the UNION ALL approach used in Queries 1 and 2, especially as the number of tables grows. While Queries 1 and 2 are functionally correct, Query 3's structure is cleaner and easier to understand, making it the preferred choice for maintainability and potential performance benefits.
# --- Decision: After SQL Judge ---
# Proceeding to execute selected SQL.
#
# --- Executing Selected SQL Query ---
# Executing query:
#
# -- Analyze the relationship between Current School, Product, and Test Scaled Score
#
# WITH
#   SchoolProductScores AS (
#     -- Combine ELA and Math data to analyze all test scores
#     SELECT
#       Current_School,
#       Product,
#       Test_Scaled_Score
#     FROM
#       `nw-ai-lab.illinois_2025_nw.iar_ela`
#     UNION ALL
#     SELECT
#       Current_School,
#       Product,
#       Test_Scaled_Score
#     FROM
#       `nw-ai-lab.illinois_2025_nw.iar_math`
#   ),
#   -- Calculate average test scores for each school and product combination
#   AvgScores AS (
#     SELECT
#       Current_School,
#       Product,
#       AVG(Test_Scaled_Score) AS Avg_Test_Scaled_Score,
#       COUNT(*) AS Number_of_Tests
#     FROM
#       SchoolProductScores
#     GROUP BY
#       Current_School,
#       Product
#   )
# -- Final SELECT statement to display the results
# SELECT
#   Current_School,
#   Product,
#   Avg_Test_Scaled_Score,
#   Number_of_Tests
# FROM
#   AvgScores
# ORDER BY
#   Current_School,
#   Product;
#
# Query executed successfully. DataFrame shape: (1, 4)
# --- Decision: After SQL Execution ---
# SQL Execution successful. Proceeding to BI Expert.
#
# --- Generating 3 BI Visualization Request Candidates ---
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.5, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating BI request candidate 1/3...
# Generating BI request candidate 2/3...
# Generating BI request candidate 3/3...
# Generated 3 total BI requests, 3 unique.
# BI Expert generated 3 candidates.
# BI Expert Total Generation Tokens: Input=3504, Output=883
#
# --- Decision: After BI Expert ---
# Generated 3 total BI requests, 3 unique.
# Proceeding to BI Judge node.
#
# --- Judging Distinct BI Requests ---
# Number of unique BI requests generated: 3
# Judging 3 unique BI requests...
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.1, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# BI Judge Raw Response:
# ```json
# {
#   "best_index": 3,
#   "reasoning": "All three requests suggest a grouped bar chart, which is appropriate. However, Request 3 is slightly better because it suggests additional considerations like color-coding and data labels, which would improve the chart's readability and usefulness. The table explanations are also more detailed in Request 3."
# }
# ```
# BI Judge selected Candidate 3.
# BI Judge Tokens: Input=3187, Output=82
# Selected Visualization Request (after judge):
# Here's a breakdown of how to visualize the relationship between `Current_School`, `Product`, and `Avg_Test_Scaled_Score`, along with the number of tests:
#
# **Chart:**
#
# *   **Chart Type:** A grouped bar chart is the most effective way to visualize this data.
# *   **Axes:**
#     *   X-axis: `Current_School`
#     *   Y-axis: `Avg_Test_Scaled_Score`
#     *   Group: `Product` (each product will have a separate bar within each school's group)
# *   **Suitability:** This chart allows for a direct comparison of average test scores for different products within each school. It makes it easy to see which product performs better in which school. The height of each bar represents the average test score, and the grouping allows for easy comparison between products.
# *   **Additional Considerations:** Color-code the bars representing different products for clarity. Add data labels to the bars to display the exact average test scores.
#
# **Table:**
#
# *   **Columns:** `Current_School`, `Product`, `Avg_Test_Scaled_Score`, `Number_of_Tests`
# *   **Usefulness:** The table provides the precise numerical values for each school-product combination. This is crucial for detailed analysis and comparison. While the bar chart gives a visual overview, the table allows users to see the exact average scores and the number of tests contributing to that average. This is especially important when the differences in average scores are small, or when the number of tests varies significantly between groups. The table also allows for sorting and filtering to identify the highest and lowest performing combinations.
# BI Judge Reasoning: All three requests suggest a grouped bar chart, which is appropriate. However, Request 3 is slightly better because it suggests additional considerations like color-coding and data labels, which would improve the chart's readability and usefulness. The table explanations are also more detailed in Request 3.
# --- Decision: After BI Judge ---
# Proceeding to Python Code Generation.
#
# --- Generating 3 Python Code Candidates ---
# visualization_request:  Here's a breakdown of how to visualize the relationship between `Current_School`, `Product`, and `Avg_Test_Scaled_Score`, along with the number of tests:
#
# **Chart:**
#
# *   **Chart Type:** A grouped bar chart is the most effective way to visualize this data.
# *   **Axes:**
#     *   X-axis: `Current_School`
#     *   Y-axis: `Avg_Test_Scaled_Score`
#     *   Group: `Product` (each product will have a separate bar within each school's group)
# *   **Suitability:** This chart allows for a direct comparison of average test scores for different products within each school. It makes it easy to see which product performs better in which school. The height of each bar represents the average test score, and the grouping allows for easy comparison between products.
# *   **Additional Considerations:** Color-code the bars representing different products for clarity. Add data labels to the bars to display the exact average test scores.
#
# **Table:**
#
# *   **Columns:** `Current_School`, `Product`, `Avg_Test_Scaled_Score`, `Number_of_Tests`
# *   **Usefulness:** The table provides the precise numerical values for each school-product combination. This is crucial for detailed analysis and comparison. While the bar chart gives a visual overview, the table allows users to see the exact average scores and the number of tests contributing to that average. This is especially important when the differences in average scores are small, or when the number of tests varies significantly between groups. The table also allows for sorting and filtering to identify the highest and lowest performing combinations.
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.3, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating Python code candidate 1/3...
# Generating Python code candidate 2/3...
# Generating Python code candidate 3/3...
# Generated 3 total Python codes, 3 unique.
# Python Generator generated 3 candidates.
# Python Generator Total Generation Tokens: Input=2205, Output=1376
#
# --- Decision: After Python Code Generator ---
# Generated 3 total Python codes, 3 unique.
# Proceeding to Python Judge node.
#
# --- Judging Distinct Python Code Candidates ---
# Number of unique Python codes generated: 3
# Judging 3 unique Python codes...
# SQL Writer using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.1, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Python Judge Raw Response:
# ```json
# {
#   "best_index": 3,
#   "reasoning": "Code snippet 3 is the best because it correctly implements the grouped bar chart as requested, creating both the `fig` and `df_viz` objects. It also includes the necessary imports and adheres to the instructions by avoiding `fig.show()`. The example data is more representative of what the function is intended to do, by including multiple schools and products. The other snippets are similar, but snippet 3's example data is slightly better."
# }
# ```
# Python Judge selected Candidate 3.
# Python Judge Tokens: Input=4247, Output=116
# Selected Python Code (after judge):
# ```python
#
# import pandas as pd
# import plotly.express as px
#
# def create_visualization(df):
#     """
#     Generates a grouped bar chart and a Pandas DataFrame based on the input DataFrame.
#
#     Args:
#         df (pd.DataFrame): Input DataFrame containing 'Current_School', 'Product',
#                            'Avg_Test_Scaled_Score', and 'Number_of_Tests' columns.
#
#     Returns:
#         tuple: A tuple containing the Plotly figure (fig) and the Pandas DataFrame (df_viz).
#     """
#     if df.empty:
#         print("No data available.")
#         return None, None
#
#     df_viz = df.copy()
#
#     # Create the grouped bar chart
#     fig = px.bar(
#         df_viz,
#         x="Current_School",
#         y="Avg_Test_Scaled_Score",
#         color="Product",
#         barmode="group",
#         text_auto=True,
#         title="Average Test Scaled Score by School and Product",
#         labels={"Avg_Test_Scaled_Score": "Average Test Scaled Score", "Current_School": "School"},
#     )
#
#     fig.update_layout(
#         xaxis_title="School",
#         yaxis_title="Average Test Scaled Score",
#         legend_title="Product",
#     )
#
#     return fig, df_viz
#
# # Example usage (replace with your actual DataFrame)
# data = {'Current_School': ['INNO', 'INNO', 'OUTO', 'OUTO'],
#         'Product': ['IAR', 'SAR', 'IAR', 'SAR'],
#         'Avg_Test_Scaled_Score': [701.124714, 650.5, 720.0, 680.75],
#         'Number_of_Tests': [874, 500, 900, 600]}
# df = pd.DataFrame(data)
# df['Number_of_Tests'] = df['Number_of_Tests'].astype('Int64')
#
# fig, df_viz = create_visualization(df)
#
# ```
# Python Judge Reasoning: Code snippet 3 is the best because it correctly implements the grouped bar chart as requested, creating both the `fig` and `df_viz` objects. It also includes the necessary imports and adheres to the instructions by avoiding `fig.show()`. The example data is more representative of what the function is intended to do, by including multiple schools and products. The other snippets are similar, but snippet 3's example data is slightly better.
# --- Decision: After Python Judge ---
# Proceeding to Python Code Validation.
#
#
# ### Validating data visualization code:
# result: Pass
#
# --- Generating 3 Insights Candidate(s) ---
# Insights Generator using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.4, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Generating Insights Candidate 1/3...
# Generating Insights Candidate 2/3...
# Generating Insights Candidate 3/3...
# Insights Generator produced 3 candidates.
# Insights Generator Total Tokens: Input=650772, Output=1052
#
# --- Decision: After Insights Generator ---
# Multiple unique insights generated. Proceeding to Insights Judge node.
#
# --- Judging Distinct Insight Candidates ---
# Number of unique insight texts to judge: 3
# Insights Judge using LLM config: {'model_name': 'gemini-2.0-flash', 'temperature': 0.4, 'project': 'nw-ai-lab', 'location': 'us-central1'}
# Invoking Insights Judge LLM...
# Insights Judge Raw Response:
# ```json
# {
#   "best_index": 3,
#   "reasoning": "Candidate 3 is the best because it provides the most comprehensive and actionable insights while adhering to the constraints. Its observations are accurate and directly supported by the data and plot. The suggestions are logically connected to the correlation matrix, and the MTSS-aligned recommendations are practical and relevant. It also correctly interprets the correlation matrix to suggest that homeroom environments impact performance, which is a valuable insight for educators. The other candidates are not as comprehensive or actionable."
# }
# ```
# Insights Judge selected Candidate 3.
# Insights Judge Tokens: Input=217081, Output=115
# Selected Insight (after judge): Here's an analysis of the provided data, focusing on actionable insights and MTSS alignment:
#
# Blurb: The data highlights a strong correlation between English and Math performance, suggesting that inte...
# Insights Judge Reasoning: Candidate 3 is the best because it provides the most comprehensive and actionable insights while adhering to the constraints. Its observations are accurate and directly supported by the data and plot. The suggestions are logically connected to the correlation matrix, and the MTSS-aligned recommendations are practical and relevant. It also correctly interprets the correlation matrix to suggest that homeroom environments impact performance, which is a valuable insight for educators. The other candidates are not as comprehensive or actionable.
# Model: gemini-2.0-flash
# Total cost: 1.5426748999999997
# Total input tokens: 15079541
# Total output tokens: 86802
# Total runs: 21
# Average run time: 43.83797295888265
# Average cost per run: 0.07346070952380951
# Average input tokens per run: 718073.380952381
# Average output tokens per run: 4133.428571428572
